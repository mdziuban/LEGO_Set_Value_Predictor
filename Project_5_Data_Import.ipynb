# %%
import pandas as pd
import numpy as np

# %%
colors = pd.read_csv('/Users/markdziuban/Desktop/workspace/Project_5/colors.csv')
elements = pd.read_csv('/Users/markdziuban/Desktop/workspace/Project_5/elements.csv')
inventories = pd.read_csv('/Users/markdziuban/Desktop/workspace/Project_5/inventories.csv')
inventory_parts = pd.read_csv('/Users/markdziuban/Desktop/workspace/Project_5/inventory_parts.csv')
inventory_sets = pd.read_csv('/Users/markdziuban/Desktop/workspace/Project_5/inventory_sets.csv')
part_categories = pd.read_csv('/Users/markdziuban/Desktop/workspace/Project_5/part_categories.csv')
part_relationships = pd.read_csv('/Users/markdziuban/Desktop/workspace/Project_5/part_relationships.csv')
parts = pd.read_csv('/Users/markdziuban/Desktop/workspace/Project_5/parts.csv')
sets = pd.read_csv('/Users/markdziuban/Desktop/workspace/Project_5/sets.csv')
themes = pd.read_csv('/Users/markdziuban/Desktop/workspace/Project_5/themes.csv')
brick_econ1 = pd.read_csv('/Users/markdziuban/Desktop/workspace/Project_5/lego_complete999.csv')
brick_econ2 = pd.read_csv('/Users/markdziuban/Desktop/workspace/Project_5/lego_complete1999.csv')
brick_econ3 = pd.read_csv('/Users/markdziuban/Desktop/workspace/Project_5/lego_complete2999.csv')
brick_econ4 = pd.read_csv('/Users/markdziuban/Desktop/workspace/Project_5/lego_complete3999.csv')
brick_econ5 = pd.read_csv('/Users/markdziuban/Desktop/workspace/Project_5/lego_complete4999.csv')
brick_econ6 = pd.read_csv('/Users/markdziuban/Desktop/workspace/Project_5/lego_complete5999.csv')
brick_econ7 = pd.read_csv('/Users/markdziuban/Desktop/workspace/Project_5/lego_complete6999.csv')
brick_econ8 = pd.read_csv('/Users/markdziuban/Desktop/workspace/Project_5/lego_complete9242.csv')

# %%
colors
# Out:
#        id                              name     rgb is_trans
# 0      -1                         [Unknown]  0033B2        f
# 1       0                             Black  05131D        f
# 2       1                              Blue  0055BF        f
# 3       2                             Green  237841        f
# 4       3                    Dark Turquoise  008F9B        f
# ..    ...                               ...     ...      ...
# 179  1053                   Trans-Blue Opal  68BCC5        t
# 180  1054  Trans-Medium Reddish Violet Opal  CE1D9B        t
# 181  1055                  Trans-Clear Opal  FCFCFC        t
# 182  1056                  Trans-Brown Opal  583927        t
# 183  9999              [No Color/Any Color]  05131D        f
#
# [184 rows x 4 columns]

# %%
elements.head()
# Out:
#   element_id part_num  color_id
# 0    4506799    42450        -1
# 1    4200351    45455        -1
# 2    4580715    89187        -1
# 3    4264154    51035        -1
# 4    6194308    92926        71

# %%
inventories.head()
# Out:
#    id  version set_num
# 0   1        1  7922-1
# 1   3        1  3931-1
# 2   4        1  6942-1
# 3  15        1  5158-1
# 4  16        1   903-1

# %%
inventory_parts.head()
# Out:
#    inventory_id     part_num  color_id  quantity is_spare
# 0             1     48379c01        72         1        f
# 1             1        48395         7         1        f
# 2             1     mcsport6        25         1        f
# 3             1       paddle         0         1        f
# 4             3  11816pr0005        78         1        f

# %%
inventory_sets.head()
# Out:
#    inventory_id  set_num  quantity
# 0            35  75911-1         1
# 1            35  75912-1         1
# 2            39  75048-1         1
# 3            39  75053-1         1
# 4            50   4515-1         1

# %%
part_categories.head()
# Out:
#    id                     name
# 0   1               Baseplates
# 1   3            Bricks Sloped
# 2   4  Duplo, Quatro and Primo
# 3   5           Bricks Special
# 4   6            Bricks Wedged

# %%
part_relationships.head()
# Out:
#   rel_type child_part_num parent_part_num
# 0        M          3192a            3192
# 1        A         50990b          50990a
# 2        P    27382pr0005           27382
# 3        P      3298pb010            3298
# 4        P   19729pr0013a           19729

# %%
parts.head()
# Out:
#   part_num                         name  part_cat_id  part_material_id
# 0   004229  Sticker Sheet for Set 295-1           58                 1
# 1   004284  Sticker Sheet for Set 723-2           58                 1
# 2   004285  Sticker Sheet for Set 725-2           58                 1
# 3   004490  Sticker Sheet for Set 365-1           58                 1
# 4   004590  Sticker Sheet for Set 182-1           58                 1

# %%
# remove all mini-figures

sets = sets[~sets['name'].str.contains('Figures')]
sets
# Out:
#            set_num                                 name  year  theme_id  \
# 0            001-1                                Gears  1965         1
# 2           0011-3           Castle 2 for 1 Bonus Offer  1987       199
# 8            002-1       4.5V Samsonite Gears Motor Set  1965         1
# 9            003-1                  Master Mechanic Set  1966       366
# 10           005-1      Basic Building Set in Cardboard  1965       366
# ...            ...                                  ...   ...       ...
# 15651      wwgp1-1  Wild West Limited Edition Gift Pack  1996       476
# 15652   XMASTREE-1                       Christmas Tree  2019       410
# 15653      XWING-1                  Mini X-Wing Fighter  2019       158
# 15654      XWING-2                    X-Wing Trench Run  2019       158
# 15655  YODACHRON-1      Yoda Chronicles Promotional Set  2013       158
#
#        num_parts
# 0             43
# 2              0
# 8              3
# 9            403
# ...

# %%
sets= sets.rename(columns={'theme_id': 'id'})

# %%
themes
# Out:
#       id                           name  parent_id
# 0      1                        Technic        NaN
# 1      2                 Arctic Technic        1.0
# 2      3                    Competition        1.0
# 3      4                 Expert Builder        1.0
# 4      5                          Model        1.0
# ..   ...                            ...        ...
# 650  685                        Galidor        NaN
# 651  686  Chinese Traditional Festivals        NaN
# 652  687                      Frozen II      608.0
# 653  688                           DOTS        NaN
# 654  689                        Minions        NaN
#
# [655 rows x 3 columns]

# %%
theme_sup = themes[themes['name']!='Universal Building Set']
theme_sup = theme_sup[themes['name']!='Supplemental']
theme_sup = theme_sup[themes['name']!='Basic Set']
theme_sup = theme_sup[themes['name']!='Basic']

list(theme_sup['name'])
# Out:
# /Users/markdziuban/opt/anaconda3/envs/metis/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/markdziuban/opt/anaconda3/envs/metis/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/markdziuban/opt/anaconda3/envs/metis/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# ['Technic',
#  'Arctic Technic',
#  'Competition',
#  'Expert Builder',
#  'Model',
#  'Airport',
#  'Construction',
#  'Farm',
#  'Fire',
#  'Harbor',
#  'Off-Road',
#  'Race',
#  'Riding Cycle',
#  'Robot',
#  'Traffic',
#  'RoboRiders',
#  'Speed Slammers',
#  'Star Wars',
#  'Throwbot Slizer',
#  'Creator',
#  'Basic Model',
#  'Airport',
# ...

# %%
new_df = sets.merge(theme_sup,on='id', how='inner')

# %%
# I need to delete these rows for the sets table.

new_df
# Out:
#            set_num                                             name_x  year  \
# 0            001-1                                              Gears  1965
# 1            002-1                     4.5V Samsonite Gears Motor Set  1965
# 2           1030-1                     TECHNIC I: Simple Machines Set  1985
# 3           1038-1                                 ERBIE the Robo-Car  1985
# 4           1039-1                               Manual Control Set 1  1986
# ...            ...                                                ...   ...
# 14420      K7623-1        Indiana Jones Classic Adventures Collection  2008
# 14421     llca27-1  Legoland Pirate with Parrot (Legoland California)  2006
# 14422     LLCA29-1  Pirate Treasure Chest Bank (LLCA Ambassador Pa...  2006
# 14423     LLCA30-1  Pirate Ship Diorama (LLCA Ambassador Pass Excl...  2006
# 14424  WEETABIX1-1                                    Weetabix Castle  1970
#
#         id  num_parts         name_y  parent_id
# ...

# %%
new_df2 = new_df[new_df['num_parts']>20]

# %%
new_df2.to_csv("lego_sets_df.csv")

# %%
lego_sets_df = pd.read_csv("lego_sets_df_old.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-30-0cf066f4a793> in <module>
# ----> 1 lego_sets_df = pd.read_csv("lego_sets_df_old.csv")
#
# ~/opt/anaconda3/envs/metis/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
sep = '-'

lego_sets_df['new_set_num'] = lego_sets_df['set_num'].apply(lambda x: x.split(sep,1)[0] )

# %%
# sep = '-'

# sets['new_set_num'] = sets['set_num'].apply(lambda x: x.split(sep,1)[0] )
lego_sets_df.head(50)
# Out:
#     Unnamed: 0   set_num                                             name_x  \
# 0            0     001-1                                              Gears
# 1            2    1030-1                     TECHNIC I: Simple Machines Set
# 2            3    1038-1                                 ERBIE the Robo-Car
# 3            4    1039-1                               Manual Control Set 1
# 4            6    1314-1                           Stop bush / Small pulley
# 5            7    1315-1                                         Piston Rod
# 6            8    1316-1                                      Connector peg
# 7            9    1317-1                                 TECHNIC Chainlinks
# 8           10    1318-1                                        Gears Small
# 9           11    1319-1                                        Gears Large
# 10          12    1320-1                       Differential and Bevel Gears
# ...

# %%
import re

lego_sets_df['name_x'] = lego_sets_df['name_x'].apply(lambda x: re.sub(r'[^A-Za-z0-9 ]+', '', x))

# %%
lego_sets_df['Search_Text'] = lego_sets_df[['name_x', 'new_set_num']].values.tolist()

# %%
search_list_full = list(lego_sets_df['Search_Text'])

# %%
lego_sets_df[lego_sets_df['set_num']=='8849-1']
# Out:
#       Unnamed: 0 set_num   name_x  year  id  num_parts name_y  parent_id  \
# 9047       13969  8849-1  Tractor  1986   8        347   Farm        5.0
#
#      new_set_num      Search_Text
# 9047        8849  [Tractor, 8849]

# %%
lego_sets_df
# Out:
#       Unnamed: 0      set_num  \
# 0              0        001-1
# 1              2       1030-1
# 2              3       1038-1
# 3              4       1039-1
# 4              6       1314-1
# ...          ...          ...
# 9265       14418    LLCABR3-1
# 9266       14421     llca27-1
# 9267       14422     LLCA29-1
# 9268       14423     LLCA30-1
# 9269       14424  WEETABIX1-1
#
#                                                  name_x  year   id  num_parts  \
# 0                                                 Gears  1965    1         43
# 1                         TECHNIC I Simple Machines Set  1985    1        191
# 2                                     ERBIE the RoboCar  1985    1        120
# 3                                  Manual Control Set 1  1986    1         39
# 4                               Stop bush  Small pulley  1987    1        210
# ...                                                 ...   ...  ...        ...
# ...

# %%
econ_dfs = [brick_econ1,brick_econ2,brick_econ3,brick_econ4,brick_econ5,brick_econ6,brick_econ7,brick_econ8]

lego_econ_df = pd.concat(econ_dfs, ignore_index=True )

# %%
lego_econ_df[lego_econ_df['Year']>2018][0:50]
# Out:
#       Unnamed: 0 Set number                               Name  \
# 57             1    42089-1                         Power Boat
# 58             1    42090-1                      Getaway Truck
# 61             1    42094-1                     Tracked Loader
# 62             1    42101-1                              Buggy
# 63             1    42102-1                  Mini CLAAS XERION
# 64             1    42103-1                           Dragster
# 66             1    42105-1                          Catamaran
# 67             1    42106-1            Stunt Show Truck & Bike
# 69             1    42109-1  App-Controlled Top Gear Rally Car
# 391            1   911944-1                  Resistance Bomber
# 426            1   791901-1                               Jack
# 427            1   891945-1                           Young Wu
# 428            1   891951-1                                Nya
# 429            1   792004-1                           El Fuego
# ...

# %%
lego_econ_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39304 entries, 0 to 39303
# Data columns (total 32 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         39304 non-null  int64
#  1   Set number         38883 non-null  object
#  2   Name               39298 non-null  object
#  3   Theme              39298 non-null  object
#  4   Subtheme           26655 non-null  object
#  5   Year               39298 non-null  float64
#  6   Availability       39198 non-null  object
#  7   Pieces             37254 non-null  object
#  8   Retail price       35951 non-null  object
#  9   Value              35443 non-null  object
#  10  Growth             26074 non-null  object
#  11  Annual growth      38827 non-null  object
#  12  Lowest price       31273 non-null  object
#  13  Sets               38995 non-null  object
#  14  Years              35137 non-null  object
#  15  Search_Term        39298 non-null  object
# ...

# %%
lego_econ_df = lego_econ_df.drop_duplicates(subset='Name')

# %%
lego_econ_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7161 entries, 0 to 39303
# Data columns (total 32 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         7161 non-null   int64
#  1   Set number         7065 non-null   object
#  2   Name               7160 non-null   object
#  3   Theme              7160 non-null   object
#  4   Subtheme           5041 non-null   object
#  5   Year               7160 non-null   float64
#  6   Availability       7146 non-null   object
#  7   Pieces             6817 non-null   object
#  8   Retail price       6733 non-null   object
#  9   Value              6505 non-null   object
#  10  Growth             5062 non-null   object
#  11  Annual growth      7062 non-null   object
#  12  Lowest price       5880 non-null   object
#  13  Sets               7090 non-null   object
#  14  Years              5998 non-null   object
#  15  Search_Term        7160 non-null   object
# ...

# %%
lego_econ_df[lego_econ_df['ISBN'].notnull()]
# Out:
#        Unnamed: 0 Set number  \
# 9834            1        NaN
# 15678           1        NaN
#
#                                                     Name  Theme Subtheme  \
# 9834   Ninjago Build Your Own Adventure Greatest Ninj...  Books      NaN
# 15678        LEGO DC Super Heroes Character Encyclopedia  Books      NaN
#
#          Year Availability          Pieces Retail price    Value  ...  \
# 9834   2018.0       Retail             NaN       $24.99      NaN  ...
# 15678  2016.0      Retired  7  (PPP $2.86)       $19.99  Unknown  ...
#
#       Mini-doll figures Released/retired Minifigs Packaging Items  \
# 9834                NaN              NaN      NaN       NaN   NaN
# 15678               NaN              NaN      NaN       NaN   NaN
#
#       Duplo figures Figures         ISBN           Publisher Books
# 9834            NaN     NaN  1.46547e+09  Dorling Kindersley  84.0
# 15678           NaN     NaN   024119931X  Dorling Kindersley  84.0
#
# [2 rows x 32 columns]

# %%
lego_econ_df = lego_econ_df.drop(labels=['Unnamed: 0'], axis=1)

# %%
# Two books were missed by the previous filter.  Remove them here by row label.

lego_econ_df = lego_econ_df[lego_econ_df['Theme']!='Books']

# %%
lego_econ_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7159 entries, 0 to 39303
# Data columns (total 31 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Set number         7065 non-null   object
#  1   Name               7158 non-null   object
#  2   Theme              7158 non-null   object
#  3   Subtheme           5041 non-null   object
#  4   Year               7158 non-null   float64
#  5   Availability       7144 non-null   object
#  6   Pieces             6816 non-null   object
#  7   Retail price       6731 non-null   object
#  8   Value              6504 non-null   object
#  9   Growth             5062 non-null   object
#  10  Annual growth      7060 non-null   object
#  11  Lowest price       5880 non-null   object
#  12  Sets               7090 non-null   object
#  13  Years              5996 non-null   object
#  14  Search_Term        7158 non-null   object
#  15  Highest price      5318 non-null   object
# ...

# %%
lego_econ_df[lego_econ_df['Items'].notnull()]
# Out:
#       Set number                               Name Theme          Subtheme  \
# 92     4329942-1                      Lunchbox Pink  Gear        Housewares
# 93     4329943-1                     Lunchbox Black  Gear        Housewares
# 185    4499574-1                        Tic Tac Toe  Gear       Board Games
# 186    4500744-1             Ludo with Mini-Figures  Gear       Board Games
# 191     852001-1                   Castle Chess Set  Gear       Board Games
# ...          ...                                ...   ...               ...
# 29694    60230-1             Bionicle Cartridge Pen  Gear        Stationery
# 37476     9402-1                      Giraffe Table  Gear         Furniture
# 37720   853872-1                         Emmet Mask  Gear    Role-Play Toys
# 38206  4250348-1       Knight's Kingdom Alarm Clock  Gear  Watches & Clocks
# 38911   853638-1  Batman Minifigure Collector Frame  Gear           Storage
#
# ...

# %%
# Remove gear since it is not a set.  

lego_econ_df = lego_econ_df[lego_econ_df['Theme']!='Gear']

# %%
lego_econ_df
# Out:
#       Set number                                      Name        Theme  \
# 0         0011-3                       2 For 1 Bonus Offer       Castle
# 1         1030-1             Technic I Simple Machines Set        Dacta
# 2         1038-1                           Universal Buggy        Dacta
# 3         1039-1                      Manual Control Set 1        Dacta
# 4        71314-1                               Storm Beast     Bionicle
# ...          ...                                       ...          ...
# 39298     9754-1                   Dark Side Developer Kit   Mindstorms
# 39299     9797-1             Mindstorms Education Base Set    Education
# 39300        NaN  Hau Mask Green Brick Legoland California  Promotional
# 39301        NaN           Pirate Treasure Chest Coin Bank  Promotional
# 39303        NaN                           Weetabix Castle     LEGOLAND
#
#               Subtheme    Year              Availability            Pieces  \
# ...

# %%
lego_econ_df[lego_econ_df['Mini-doll figures'].notnull()][0:50]
# Out:
#      Set number                           Name    Theme        Subtheme  \
# 7       41317-1             Sunshine Catamaran  Friends          Summer
# 8       41318-1             Heartlake Hospital  Friends             NaN
# 9       41319-1  Snow Resort Hot Chocolate Van  Friends     Snow Resort
# 10      41320-1   Heartlake Frozen Yogurt Shop  Friends             NaN
# 11      41321-1         Snow Resort Off-Roader  Friends     Snow Resort
# 12      41322-1           Snow Resort Ice Rink  Friends     Snow Resort
# 13      41324-1           Snow Resort Ski Lift  Friends     Snow Resort
# 14      41325-1      Heartlake City Playground  Friends             NaN
# 15      41326-1        Friends Advent Calendar  Friends        Seasonal
# 16      41345-1      Heartlake City Pet Centre  Friends             NaN
# 2433    41116-1       Olivia's Exploration Car  Friends             NaN
# 2434    41135-1          Livi's Pop Star House  Friends        Pop Star
# ...

# %%
# move the mini-doll figures and figures info into minifigs column.  
# fill the rest with zeros

lego_econ_df['Minifigs'] = lego_econ_df['Minifigs'].fillna(lego_econ_df['Mini-doll figures'])
lego_econ_df['Minifigs'] = lego_econ_df['Minifigs'].fillna(lego_econ_df['Figures'])
lego_econ_df['Minifigs'] = lego_econ_df['Minifigs'].fillna(0)

# %%
lego_econ_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7092 entries, 0 to 39303
# Data columns (total 31 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Set number         6999 non-null   object
#  1   Name               7091 non-null   object
#  2   Theme              7091 non-null   object
#  3   Subtheme           4975 non-null   object
#  4   Year               7091 non-null   float64
#  5   Availability       7077 non-null   object
#  6   Pieces             6816 non-null   object
#  7   Retail price       6667 non-null   object
#  8   Value              6444 non-null   object
#  9   Growth             5031 non-null   object
#  10  Annual growth      7000 non-null   object
#  11  Lowest price       5853 non-null   object
#  12  Sets               7090 non-null   object
#  13  Years              5931 non-null   object
#  14  Search_Term        7091 non-null   object
#  15  Highest price      5294 non-null   object
# ...

# %%
lego_econ_df[lego_econ_df['Released/retired'].notnull()]
# Out:
#       Set number                                               Name  \
# 17       41999-1                      4x4 Crawler Exclusive Edition
# 46        8283-1                                        Telehandler
# 1959     40254-1                                         Nutcracker
# 2099     40204-1                                    Pilgrim's Feast
# 2121         NaN                   Berlin Exclusive Minifigure Pack
# 2132         NaN                                  Tree in the Woods
# 2233         NaN                                      Golden Snitch
# 6024   5004590-1                                            Bat-Pod
# 9879     30426-1                             Stealthy Swamp Airboat
# 10065        NaN                            Micro Electromech Robot
# 10066        NaN                                Micro Shinto Shrine
# 10296    30496-1                                     U-Wing Fighter
# 10306    40288-1                                               BB-8
# ...

# %%
lego_econ_df = lego_econ_df.drop(labels=['Books','Publisher','ISBN','Figures','Items','Packaging','Mini-doll figures','Future growth'], axis=1)

# %%
lego_econ_df = lego_econ_df.drop(labels=['Growth','Price','Average price','Released/retired'], axis=1)

# %%
lego_econ_df = lego_econ_df.drop(labels=['Annual growth'], axis=1)

# %%
lego_econ_df = lego_econ_df.drop(labels=['Highest price'], axis=1)

# %%
# drop the one row with all nulls

lego_econ_df = lego_econ_df.dropna(subset=['Year'])

# %%
lego_econ_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7091 entries, 0 to 39303
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Set number     6999 non-null   object
#  1   Name           7091 non-null   object
#  2   Theme          7091 non-null   object
#  3   Subtheme       4975 non-null   object
#  4   Year           7091 non-null   float64
#  5   Availability   7077 non-null   object
#  6   Pieces         6816 non-null   object
#  7   Retail price   6667 non-null   object
#  8   Value          6444 non-null   object
#  9   Lowest price   5853 non-null   object
#  10  Sets           7090 non-null   object
#  11  Years          5931 non-null   object
#  12  Search_Term    7091 non-null   object
#  13  Released       3501 non-null   object
#  14  Retired        2464 non-null   object
#  15  Minifigs       7091 non-null   float64
#  16  Duplo figures  282 non-null    float64
# ...

# %%
lego_econ_df = lego_econ_df.drop(labels=['Lowest price'], axis=1)

# %%
lego_econ_df[(lego_econ_df['Retired'].isnull()) & (lego_econ_df['Availability']=='Retired')]
# Out:
#       Set number                                      Name        Theme  \
# 1         1030-1             Technic I Simple Machines Set        Dacta
# 2         1038-1                           Universal Buggy        Dacta
# 3         1039-1                      Manual Control Set 1        Dacta
# 12       41322-1                      Snow Resort Ice Rink      Friends
# 18         663-1                                Hovercraft     LEGOLAND
# ...          ...                                       ...          ...
# 39298     9754-1                   Dark Side Developer Kit   Mindstorms
# 39299     9797-1             Mindstorms Education Base Set    Education
# 39300        NaN  Hau Mask Green Brick Legoland California  Promotional
# 39301        NaN           Pirate Treasure Chest Coin Bank  Promotional
# 39303        NaN                           Weetabix Castle     LEGOLAND
#
#           Subtheme    Year Availability            Pieces      Retail price  \
# ...

# %%
lego_econ_df['Duplo figures'] = lego_econ_df['Duplo figures'].fillna(0)

# %%
lego_econ_df['Year'] = lego_econ_df['Year'].astype(str)

# %%
lego_econ_df['Years'] = lego_econ_df['Years'].fillna(lego_econ_df['Year'])

# %%
lego_econ_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7091 entries, 0 to 39303
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Set number     6999 non-null   object
#  1   Name           7091 non-null   object
#  2   Theme          7091 non-null   object
#  3   Subtheme       4975 non-null   object
#  4   Year           7091 non-null   object
#  5   Availability   7077 non-null   object
#  6   Pieces         6816 non-null   object
#  7   Retail price   6667 non-null   object
#  8   Value          6444 non-null   object
#  9   Sets           7090 non-null   object
#  10  Years          7091 non-null   object
#  11  Search_Term    7091 non-null   object
#  12  Released       3501 non-null   object
#  13  Retired        2464 non-null   object
#  14  Minifigs       7091 non-null   float64
#  15  Duplo figures  7091 non-null   float64
# dtypes: float64(2), object(14)
# memory usage: 941.8+ KB

# %%
lego_econ_df[lego_econ_df['Value'].isnull()]
# Out:
#       Set number                          Name      Theme          Subtheme  \
# 13       41324-1          Snow Resort Ski Lift    Friends       Snow Resort
# 16       41345-1     Heartlake City Pet Centre    Friends               NaN
# 19       60180-1                 Monster Truck       City           Traffic
# 54       42070-1     6x6 All Terrain Tow Truck    Technic               NaN
# 55       42079-1           Heavy Duty Forklift    Technic               NaN
# ...          ...                           ...        ...               ...
# 39054    75975-1          Watchpoint Gibraltar  Overwatch               NaN
# 39055    75976-1                 Wrecking Ball  Overwatch               NaN
# 39056    75977-1             Junkrat & Roadhog  Overwatch               NaN
# 39092    80103-1              Dragon Boat Race   Seasonal  Chinese New Year
# 39094    80105-1  Chinese New Year Temple Fair   Seasonal  Chinese New Year
#
# ...

# %%
def split_years(row, return_value = 0):
    print(row)
    if row is 'nan':
        print('None')
        return None
    else:
        list_row = row.split(' ')
        print(list_row[return_value])
        return list_row[return_value]

# %%
lego_econ_df['release_year'] = lego_econ_df['Years'].apply(lambda x: split_years(x,0))
# Out:
# 1987 - 2005
# 1987
# 1984 - 2003
# 1984
# 1984 - 2003
# 1984
# 1960 - 2003
# 1960
# 2015 - 2016
# 2015
# 2015 - 2016
# 2015
# 2015 - 2016
# 2015
# 2013 - 2018
# 2013
# 2012 - 2020
# 2012
# 2017.0
# 2017.0
# 2012 - 2020
# 2012
# 2017.0
# 2017.0
# 2017.0
# 2017.0
# 2017.0
# 2017.0
# 2012 - 2020
# 2012
# 2012 - 2019
# 2012
# 2012 - 2020
# 2012
# 1977 - 2020
# 1977
# 1970 - 1977
# 1970
# 2007 - 2020
# 2007
# 1978 - 1981
# 1978
# 1977 - 2020
# 1977
# 1977 - 2020
# 1977
# 1977 - 2020
# 1977
# 1978 - 2004
# 1978
# 1977 - 2020
# 1977
# 1977 - 2020
# 1977
# 1977 - 2020
# 1977
# 1980 - 1997
# 1980
# 1977 - 2020
# 1977
# 1977 - 2020
# 1977
# 2002 - 2004
# 2002
# 1977 - 2020
# 1977
# 1977 - 2020
# 1977
# 1977 - 2020
# 1977
# 1977 - 2020
# 1977
# 1977 - 2020
# 1977
# 1977 - 2020
# 1977
# 1977 - 2020
# 1977
# 1977 - 2020
# 1977
# 1977 - 2020
# 1977
# 1977 - 2020
# 1977
# 1977 - 2020
# 1977
# 1977 - 2020
# 1977
# 1977 - 2020
# 1977
# 1977 - 2020
# 1977
# 1977 - 2020
# 1977
# 1977 - 2020
# 1977
# ...

# %%
lego_econ_df[0:50]
# Out:
#    Set number                           Name     Theme         Subtheme  \
# 0      0011-3            2 For 1 Bonus Offer    Castle      Value Packs
# 1      1030-1  Technic I Simple Machines Set     Dacta          Technic
# 2      1038-1                Universal Buggy     Dacta          Technic
# 3      1039-1           Manual Control Set 1     Dacta              NaN
# 4     71314-1                    Storm Beast  Bionicle  Reboot Villains
# 5     71315-1                    Quake Beast  Bionicle  Reboot Villains
# 6     71316-1           Umarak the Destroyer  Bionicle  Reboot Villains
# 7     41317-1             Sunshine Catamaran   Friends           Summer
# 8     41318-1             Heartlake Hospital   Friends              NaN
# 9     41319-1  Snow Resort Hot Chocolate Van   Friends      Snow Resort
# 10    41320-1   Heartlake Frozen Yogurt Shop   Friends              NaN
# 11    41321-1         Snow Resort Off-Roader   Friends      Snow Resort
# ...

# %%
lego_econ_df['Retail price'] = lego_econ_df['Retail price'].apply(lambda x: 0 if x =='Included with magazine' else x)

# %%
lego_econ_df['Retail price'].value_counts()
# Out:
# $19.99              653
# $9.99               541
# Free promotional    530
# $29.99              468
# $14.99              345
#                    ...
# $72.00                1
# $63.75                1
# $135.00               1
# $121.95               1
# $45.90                1
# Name: Retail price, Length: 320, dtype: int64

# %%
lego_econ_df['Retail price'] = lego_econ_df['Retail price'].apply(lambda x: 0 if x =='Free promotional' else x)

# %%
lego_econ_df['Retail price'] = lego_econ_df['Retail price'].fillna(-999999)

# %%
lego_econ_df['Retail price'] = lego_econ_df['Retail price'].replace('[\$,]', '', regex=True).astype(float)

# %%
lego_econ_df = lego_econ_df.reset_index()

# %%
lego_econ_df['Pieces'] = lego_econ_df['Pieces'].astype(str)

# %%
lego_econ_df['Pieces'] = lego_econ_df['Pieces'].apply(lambda x: x.split()[0])

# %%
lego_econ_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7091 entries, 0 to 7090
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          7091 non-null   int64
#  1   Set number     6999 non-null   object
#  2   Name           7091 non-null   object
#  3   Theme          7091 non-null   object
#  4   Subtheme       4975 non-null   object
#  5   Year           7091 non-null   object
#  6   Availability   7077 non-null   object
#  7   Pieces         7091 non-null   object
#  8   Retail price   7091 non-null   float64
#  9   Value          6444 non-null   object
#  10  Sets           7090 non-null   object
#  11  Years          7091 non-null   object
#  12  Search_Term    7091 non-null   object
#  13  Released       3501 non-null   object
#  14  Retired        2464 non-null   object
#  15  Minifigs       7091 non-null   float64
#  16  Duplo figures  7091 non-null   float64
# ...

# %%
lego_econ_df['Pieces'] = lego_econ_df['Pieces'].apply(lambda x: -999999 if x == 'nan' else x)

# %%
lego_econ_df['Retail price'].value_counts()
# Out:
#  19.99        653
#  0.00         622
#  9.99         541
#  29.99        468
# -999999.00    424
#              ...
#  39.49          1
#  229.95         1
#  245.99         1
#  55.00          1
#  7.50           1
# Name: Retail price, Length: 320, dtype: int64

# %%
#lego_econ_df['Pieces'] = lego_econ_df['Pieces'].replace('[\,]', '', regex=True).astype(int)

#lego_econ_df['Pieces'] = lego_econ_df['Pieces'].apply(lambda x: -999999 if x == 'nan' else x)

# %%
lego_econ_df['Pieces'] = lego_econ_df['Pieces'].replace('[\,]', '', regex=True).astype(int)

# %%
lego_econ_df['Pieces'].value_counts()
# Out:
# -999999    275
#  25         96
#  28         80
#  24         76
#  21         75
#           ...
#  1969        1
#  4016        1
#  1869        1
#  1849        1
#  2049        1
# Name: Pieces, Length: 1082, dtype: int64

# %%
lego_econ_df['Price_Per_Piece'] = lego_econ_df['Retail price'] / lego_econ_df['Pieces']

# %%
ppp_df = lego_econ_df[lego_econ_df['Price_Per_Piece'] > 0]

# %%
ppp_df
# Out:
#       index Set number                                        Name  \
# 0         0     0011-3                         2 For 1 Bonus Offer
# 1         1     1030-1               Technic I Simple Machines Set
# 4         4    71314-1                                 Storm Beast
# 5         5    71315-1                                 Quake Beast
# 6         6    71316-1                        Umarak the Destroyer
# ...     ...        ...                                         ...
# 7083  39295     9793-1  Team Challenge Set with Serial Transmitter
# 7084  39296     9795-1                       Intelligent House Set
# 7085  39297     9748-1                         Droid Developer Kit
# 7086  39298     9754-1                     Dark Side Developer Kit
# 7087  39299     9797-1               Mindstorms Education Base Set
#
#            Theme         Subtheme    Year              Availability  Pieces  \
# 0         Castle      Value Packs  1987.0  Retired (Limited Retail)     151
# ...

# %%
mean_ppp = ppp_df['Price_Per_Piece'].mean()

# %%
mean_ppp
# Out:
# 0.19382222749264527

# %%
lego_econ_df['Price_Per_Piece'] = lego_econ_df['Price_Per_Piece'].apply(lambda x: mean_ppp if x <0 else x)

# %%
lego_econ_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7091 entries, 0 to 7090
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            7091 non-null   int64
#  1   Set number       6999 non-null   object
#  2   Name             7091 non-null   object
#  3   Theme            7091 non-null   object
#  4   Subtheme         4975 non-null   object
#  5   Year             7091 non-null   object
#  6   Availability     7077 non-null   object
#  7   Pieces           7091 non-null   int64
#  8   Retail price     7091 non-null   float64
#  9   Value            6444 non-null   object
#  10  Sets             7090 non-null   object
#  11  Years            7091 non-null   object
#  12  Search_Term      7091 non-null   object
#  13  Released         3501 non-null   object
#  14  Retired          2464 non-null   object
#  15  Minifigs         7091 non-null   float64
# ...

# %%
lego_econ_df
# Out:
#       index Set number                                      Name        Theme  \
# 0         0     0011-3                       2 For 1 Bonus Offer       Castle
# 1         1     1030-1             Technic I Simple Machines Set        Dacta
# 2         2     1038-1                           Universal Buggy        Dacta
# 3         3     1039-1                      Manual Control Set 1        Dacta
# 4         4    71314-1                               Storm Beast     Bionicle
# ...     ...        ...                                       ...          ...
# 7086  39298     9754-1                   Dark Side Developer Kit   Mindstorms
# 7087  39299     9797-1             Mindstorms Education Base Set    Education
# 7088  39300        NaN  Hau Mask Green Brick Legoland California  Promotional
# 7089  39301        NaN           Pirate Treasure Chest Coin Bank  Promotional
# 7090  39303        NaN                           Weetabix Castle     LEGOLAND
#
# ...

# %%
#lego_econ_df = lego_econ_df.drop(labels=['Released', 'Retired'], axis=1)

# %%
lego_econ_df = lego_econ_df.rename(columns={'Year':'Year_Released', 
                                             'Retail price': 'Retail_Price', 
                                             'Value':'Current_Value',
                                             'Sets':'Current_Sets_For_Sale'
                                             })

# %%
lego_econ_df = lego_econ_df.drop(columns=['index'])

# %%
lego_econ_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7091 entries, 0 to 7090
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Set number             6999 non-null   object
#  1   Name                   7091 non-null   object
#  2   Theme                  7091 non-null   object
#  3   Subtheme               4975 non-null   object
#  4   Year_Released          7091 non-null   object
#  5   Availability           7077 non-null   object
#  6   Pieces                 7091 non-null   int64
#  7   Retail_Price           7091 non-null   float64
#  8   Current_Value          6444 non-null   object
#  9   Current_Sets_For_Sale  7090 non-null   object
#  10  Years                  7091 non-null   object
#  11  Search_Term            7091 non-null   object
#  12  Released               3501 non-null   object
#  13  Retired                2464 non-null   object
# ...

# %%
# fix the retail price by multiplying the the average cost per piece by number of pieces
def mult_ppp(row):
    if row.Retail_Price <0:
        return mean_ppp*row.Pieces
    else:
        return row.Retail_Price
    
lego_econ_df['Retail_Price'] = lego_econ_df.apply(mult_ppp, axis=1 )

# %%
lego_econ_df = lego_econ_df[lego_econ_df['Current_Value']!='Unknown']

# %%
lego_econ_df
# Out:
#      Set number                             Name        Theme  \
# 0        0011-3              2 For 1 Bonus Offer       Castle
# 1        1030-1    Technic I Simple Machines Set        Dacta
# 2        1038-1                  Universal Buggy        Dacta
# 3        1039-1             Manual Control Set 1        Dacta
# 4       71314-1                      Storm Beast     Bionicle
# ...         ...                              ...          ...
# 7085     9748-1              Droid Developer Kit   Mindstorms
# 7086     9754-1          Dark Side Developer Kit   Mindstorms
# 7087     9797-1    Mindstorms Education Base Set    Education
# 7089        NaN  Pirate Treasure Chest Coin Bank  Promotional
# 7090        NaN                  Weetabix Castle     LEGOLAND
#
#              Subtheme Year_Released              Availability  Pieces  \
# 0         Value Packs        1987.0  Retired (Limited Retail)     151
# 1             Technic        1985.0                   Retired     179
# ...

# %%
lego_econ_df = lego_econ_df.drop(columns=['Released','Retired'])

# %%
lego_econ_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6685 entries, 0 to 7090
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Set number             6621 non-null   object
#  1   Name                   6685 non-null   object
#  2   Theme                  6685 non-null   object
#  3   Subtheme               4763 non-null   object
#  4   Year_Released          6685 non-null   object
#  5   Availability           6671 non-null   object
#  6   Pieces                 6685 non-null   int64
#  7   Retail_Price           6685 non-null   float64
#  8   Current_Value          6038 non-null   object
#  9   Current_Sets_For_Sale  6684 non-null   object
#  10  Years                  6685 non-null   object
#  11  Search_Term            6685 non-null   object
#  12  Minifigs               6685 non-null   float64
#  13  Duplo figures          6685 non-null   float64
# ...

# %%
# use the average rate of inflation of 3.5% to calculate inflation value. 
lego_econ_df['Current_Value'] = lego_econ_df['Current_Value'].astype(str)
lego_econ_df['Current_Value'] = lego_econ_df['Current_Value'].apply(lambda x: x.split(" ")[0])

# %%
lego_econ_df['Current_Value'] = lego_econ_df['Current_Value'].replace('[\$,]', '', regex=True).astype(float)

# %%
lego_econ_df['Current_Value'] = lego_econ_df['Current_Value'].fillna(lego_econ_df['Retail_Price'])

# %%
lego_econ_df['Subtheme'] = lego_econ_df['Subtheme'].fillna('None')

# %%
set_num = lego_econ_df[lego_econ_df['Set number'].isnull()]

# %%
set_num
# Out:
#      Set number                                     Name        Theme  \
# 507         NaN           1x4x3 Thin Wall Element, Clear  Bulk Bricks
# 508         NaN   2x4 Ridge Roof Tiles, Low Sloped Black  Bulk Bricks
# 509         NaN     2x4 Ridge Roof Tiles, Low Sloped Red  Bulk Bricks
# 511         NaN                          Flags and Posts  Bulk Bricks
# 684         NaN                     Mini Harley Davidson  Promotional
# ...         ...                                      ...          ...
# 6538        NaN  Cities of Wonders Singapore Chilli Crab  Promotional
# 6539        NaN  Cities of Wonders Singapore Nyonya Kueh  Promotional
# 6907        NaN                                 Ganymede    Overwatch
# 7089        NaN          Pirate Treasure Chest Coin Bank  Promotional
# 7090        NaN                          Weetabix Castle     LEGOLAND
#
#                Subtheme Year_Released         Availability  Pieces  \
# ...

# %%
end_goal = pd.merge(lego_econ_df, sets, left_on='Name', right_on='name')

# %%
end_goal[end_goal['Pieces']<1]
# Out:
#      Set number                Name       Theme       Subtheme Year_Released  \
# 374     45002-1   Tech Machines Set   Education           None        2013.0
# 375     45002-1   Tech Machines Set   Education           None        2013.0
# 376     45002-1   Tech Machines Set   Education           None        2013.0
# 391     45025-1      Coding Express   Education           None        2018.0
# 420    891609-1                 Kai     Ninjago  Magazine Gift        2016.0
# ...         ...                 ...         ...            ...           ...
# 5615        NaN  Cologne Brickheadz  BrickHeadz    Promotional        2019.0
# 5888     7618-1             Fun Zoo       Duplo           None        2009.0
# 5889     7618-1             Fun Zoo       Duplo           None        2009.0
# 6358    81001-1          Shark Skin       FORMA           None        2019.0
# 6360    81003-1        Ink Koi Skin       FORMA           None        2019.0
#
# ...

# %%
# this needs to be fixed later.  Did I need to change pieces to -999999?

end_goal['Pieces'] = end_goal['Pieces'].apply(lambda x: None if x<0 else x)

# %%
end_goal['Pieces'] = end_goal['Pieces'].fillna(end_goal['num_parts'])

# %%
end_goal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6456 entries, 0 to 6481
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   6456 non-null   object
#  1   Theme                  6456 non-null   object
#  2   Subtheme               6456 non-null   object
#  3   Year_Released          6456 non-null   object
#  4   Availability           6456 non-null   object
#  5   Retail_Price           6456 non-null   float64
#  6   Current_Value          6456 non-null   float64
#  7   Current_Sets_For_Sale  6456 non-null   object
#  8   Years                  6456 non-null   object
#  9   Minifigs               6456 non-null   float64
#  10  Duplo figures          6456 non-null   float64
#  11  Price_Per_Piece        6456 non-null   float64
#  12  set_num                6456 non-null   object
#  13  id                     6456 non-null   int64
# ...

# %%
end_goal['Current_Sets_For_Sale'] = end_goal["Current_Sets_For_Sale"].fillna(0)

# %%
end_goal = end_goal.drop(columns=['Set number','Search_Term','release_year','name','year','Pieces'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-171-afd175e7281a> in <module>
# ----> 1 end_goal = end_goal.drop(columns=['Set number','Search_Term','release_year','name','year','Pieces'])
#       2 end_goal = end_goal.dropna()
#
# ~/opt/anaconda3/envs/metis/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3992             level=level,
#    3993             inplace=inplace,
# -> 3994             errors=errors,
#    3995         )
#    3996
#
# ~/opt/anaconda3/envs/metis/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3933         for axis, labels in axes.items():
#    3934             if labels is not None:
# -> 3935                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3936
# ...

# %%
end_goal = end_goal.dropna()

# %%
end_goal = end_goal[end_goal['Retail_Price']>-1]
end_goal
# Out:
#                       Name       Theme         Subtheme Year_Released  \
# 0     Manual Control Set 1       Dacta             None        1986.0
# 1              Storm Beast    Bionicle  Reboot Villains        2016.0
# 2              Quake Beast    Bionicle  Reboot Villains        2016.0
# 3     Umarak the Destroyer    Bionicle  Reboot Villains        2016.0
# 4       Sunshine Catamaran     Friends           Summer        2017.0
# ...                    ...         ...              ...           ...
# 6477                 Tarix    Bionicle        Glatorian        2009.0
# 6478                Strakk    Bionicle        Glatorian        2009.0
# 6479                 Vorox    Bionicle        Glatorian        2009.0
# 6480   Droid Developer Kit  Mindstorms        Star Wars        1999.0
# 6481       Weetabix Castle    LEGOLAND      Promotional        1970.0
#
#      Availability  Retail_Price  Current_Value Current_Sets_For_Sale  \
# ...

# %%
end_goal.to_csv('clean_lego_data.csv')
